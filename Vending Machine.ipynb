# %%
snack = {
    "item_1": {"ID": 1, "Name": "Chips", "Price": 2,},
    "item_2":{"ID": 2, "Name": "Chocolate Bar", "Price": 3,},
    "item_3":{"ID":3, "Name":"Sunflower Seeds", "Price":1,},
    "item_4":{"ID":4, "Name":"Salted Bisquits", "Price":3,},
    "item_5":{"ID":5, "Name":"Chewing Gum", "Price":1,},
}

cold_drinks= {
    "item_6":{"ID":6, "Name":"Ice Tea", "Price":2,},
    "item_7":{"ID":7, "Name":"Bottled water", "Price":1,},
    "item_8":{ "ID":8, "Name":"Chocolate Milk", "Price":3,},
    "item_9":{"ID":9, "Name":"Pepsi", "Price":3,},
    "item_10":{"ID":10, "Name":"Sprite", "Price":3,},
    "item_11":{ "ID":11, "Name":"Fanta", "Price":3,},
}

hot_drinks = {
    "item_12":{"ID":12, "Name":"Tea", "Price":1,},
    "item_13":{ "ID":13, "Name":"Black Coffee", "Price":3,},
    "item_14":{ "ID":14, "Name":"Latte", "Price": 3,},
    "item_15":{ "ID":15, "Name":"Cappuccino", "Price":3,},
    "item_16":{ "ID":16, "Name":"Hot Chocolate", "Price":3,},
    "item_17":{ "ID":17, "Name":"Chai", "Price":1,},
}

all_items = {
    "item_1": {"ID": 1, "Name": "Chips", "Price": 2,},
    "item_2":{"ID": 2, "Name": "Chocolate Bar", "Price": 3,},
    "item_3":{"ID":3, "Name":"Sunflower Seeds", "Price":1,},
    "item_4":{"ID":4, "Name":"Salted Bisquits", "Price":3,},
    "item_5":{"ID":5, "Name":"Chewing Gum", "Price":1,},
    "item_6":{"ID":6, "Name":"Ice Tea", "Price":2,},
    "item_7":{"ID":7, "Name":"Bottled water", "Price":1,},
    "item_8":{ "ID":8, "Name":"Chocolate Milk", "Price":3,},
    "item_9":{"ID":9, "Name":"Pepsi", "Price":3,},
    "item_10":{"ID":10, "Name":"Sprite", "Price":3,},
    "item_11":{ "ID":11, "Name":"Fanta", "Price":3,},
    "item_12":{"ID":12, "Name":"Tea", "Price":1,},
    "item_13":{ "ID":13, "Name":"Black Coffee", "Price":3,},
    "item_14":{ "ID":14, "Name":"Latte", "Price": 3,},
    "item_15":{ "ID":15, "Name":"Cappuccino", "Price":3,},
    "item_16":{ "ID":16, "Name":"Hot Chocolate", "Price":3,},
    "item_17":{ "ID":17, "Name":"Chai", "Price":1,},
}

print("Welcome to our vending maching!")
category=str(input("Would you like a Snack or Beverage? "))

if category=="Snack":
    print(snack["item_1"])
    print(snack["item_2"])
    print(snack["item_3"])
    print(snack["item_4"])
    print(snack["item_5"])

elif category=="Beverage":
    hotorcold=str(input("Hot or Cold? "))
    
    
    if hotorcold=="Cold":
        print(cold_drinks["item_6"])
        print(cold_drinks["item_7"])
        print(cold_drinks["item_8"])
        print(cold_drinks["item_9"])
        print(cold_drinks["item_10"])
        print(cold_drinks["item_11"])
    
    elif hotorcold=="Hot":
        print(hot_drinks["item_12"])
        print(hot_drinks["item_13"])
        print(hot_drinks["item_14"])
        print(hot_drinks["item_15"])
        print(hot_drinks["item_16"])
        print(hot_drinks["item_17"])     
    
    else:
        print("Invalid option, Please Restart")
else:
        print("Invalid option, Please Restart")    

product=str(input("Enter \"item_\" followed by the ID of the item you want to buy: "))

print("Selected item: ", all_items[product])

price=all_items[product]["Price"]

coins=int(input("Please insert coins"))

change=coins-price

if coins==price:
    print("Purhcase Successful!")
    print("Your Item: ",all_items[product]["Name"])
elif coins>price:
    print("Purches Successfu!")
    print("Here is your change: ",change)
else:
    print("Purchase Unsuccessful. Please restart.")
# Out:
# Welcome to our vending maching!
# {'ID': 12, 'Name': 'Tea', 'Price': 1}
# {'ID': 13, 'Name': 'Black Coffee', 'Price': 3}
# {'ID': 14, 'Name': 'Latte', 'Price': 3}
# {'ID': 15, 'Name': 'Cappuccino', 'Price': 3}
# {'ID': 16, 'Name': 'Hot Chocolate', 'Price': 3}
# {'ID': 17, 'Name': 'Chai', 'Price': 1}
# Selected item:  {'ID': 13, 'Name': 'Black Coffee', 'Price': 3}
# Purches Successfu!
# Here is your change:  2
