# %%
snack = [
    {
    "snack id":1,
    "snack name": 'Chips',
    "snack price": "2 AED",
    },
    {
    "snack id":2,
    "snack name":"Chocolate Bar",
    "snack price": "3 AED",
    },
    {
    "snack id":3,
    "snack name":"Sunflower Seeds",
    "snack price": "1 AED",
    },
    {
    "snack id":4,
    "snack name":"Salted Bisquits",
    "snack price": "3 AED",
    },
    {
    "snack id":5,
    "snack name":"Chewing Gum",
    "snack price": "1 AED",
    },

    ]

cold_drinks= [
    {
    "cold id":6,
    "cold name":"Ice Tea",
    "cold price": "2 AED",
    },
    {
    "cold id":7,
    "cold name":"Bottled water",
    "cold price": "1 AED",
    },
    {
    "cold id":8,
    "cold name":"Chocolate Milk",
    "cold price": "3 AED",
    },
    {
    "cold id":9,
    "cold name":"Pepsi",
    "cold price": "3 AED",
    },
    {
    "cold id":10,
    "cold name":"Sprite",
    "cold price": "3 AED",
    },
    {
    "cold id":11,
    "cold name":"Fanta",
    "cold price": "3 AED",
    },
    ]

hot_drinks = [
    {
    "hot id":12,
    "hot name":"Tea",
    "hot price": "1 AED",
    },
    {
    "hot id":13,
    "hot name":"Black Coffee",
    "hot price": "3 AED",
    },
    {
    "hot id":14,
    "hot name":"Latte",
    "hot price": "3 AED",
    },
    {
    "hot id":15,
    "hot name":"Cappuccino",
    "hot price": "3 AED",
    },
    {
    "hot id":16,
    "hot name":"Hot Chocolate",
    "hot price": "3 AED",
    },
    {
    "hot id":17,
    "hot name":"Chai",
    "hot price": "1 AED",
    },

    ]

print("Welcome to our vending maching!")
category=str(input("Would you like a Snack or Beverage? "))

if category=="Snack":
    for x in snack:
        print(f"ID: {x['snack id']} | {x['snack name']} | Price: {x['snack price']}")

elif category=="Beverage":
    hotorcold=str(input("Hot or Cold? "))
    if hotorcold=="Hot":
        for x in hot_drinks:
            print(f"ID: {x['hot id']} | {x['hot name']} | Price: {x['hot price']}")

    elif hotorcold=="Cold":
        for x in cold_drinks:
            print(f"ID: {x['cold id']} | {x['cold name']} | Price: {x['cold price']}")
    else:
        print("Invalid option, Please Restart")
else:
        print("Invalid option, Please Restart")    

product=int(input("Enter ID of the item you want to buy:"))

if product==1:
    print("Chip | Price: 2 AED")
    coins=int(input("Insert coins: "))
    if coins==2:
        print("Purchase Succesful!")
    elif coins>2:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==2:
    print("Chocolate Bar | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==3:
    print("Sunflower Seeds | Price: 1 AED")
    coins=int(input("Insert coins: "))
    if coins==1:
        print("Purchase Succesful!")
    elif coins>1:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==4:
    print("Salted Bisquits | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==5:
    print("Chewing Gum | Price: 1 AED")
    coins=int(input("Insert coins: "))
    if coins==1:
        print("Purchase Succesful!")
    elif coins>1:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==6:
    print("Ice Tea | Price: 2 AED")
    coins=int(input("Insert coins: "))
    if coins==2:
        print("Purchase Succesful!")
    elif coins>2:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==7:
    print("Bottled Water | Price: 1 AED")
    coins=int(input("Insert coins: "))
    if coins==1:
        print("Purchase Succesful!")
    elif coins>1:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==8:
    print("Chocolate Milk | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==9:
    print("Pepsi | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==10:
    print("Sprite | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==11:
    print("Fanta | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==12:
    print("Tea | Price: 1 AED")
    coins=int(input("Insert coins: "))
    if coins==1:
        print("Purchase Succesful!")
    elif coins>1:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==13:
    print("Black Coffee | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==14:
    print("Latte | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==15:
    print("Cappuccino | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==16:
    print("Hot Chocolate | Price: 3 AED")
    coins=int(input("Insert coins: "))
    if coins==3:
        print("Purchase Succesful!")
    elif coins>3:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
elif product==17:
    print("Chai | Price: 1 AED")
    coins=int(input("Insert coins: "))
    if coins==1:
        print("Purchase Succesful!")
    elif coins>1:
        print("Purhcase successful! Here is your change.")
    else:
        print("Purchase unsuccesful. Please enter the right ammount of coins.")
# Out:
# Welcome to our vending maching!
# ID: 1 | Chips | Price: 2 AED
# ID: 2 | Chocolate Bar | Price: 3 AED
# ID: 3 | Sunflower Seeds | Price: 1 AED
# ID: 4 | Salted Bisquits | Price: 3 AED
# ID: 5 | Chewing Gum | Price: 1 AED
# Salted Bisquits | Price: 3 AED
# Purhcase successful! Here is your change.
